# %%
from google.colab import userdata
token = userdata.get('GITHUB_TOKEN')
# !git clone https://oauth2:{token}@github.com/julianszere/logit-linear-selection.git
# %cd logit-linear-selection
# !pip install -r requirements.txt
# !pip uninstall -y torchao

# %%
from google.colab import userdata
from huggingface_hub import login
import os

hf_token = userdata.get('HF_TOKEN')
os.environ['HF_HOME'] = '/content/.hf'
os.environ['HF_TOKEN'] = hf_token
login(token=hf_token)

# %%
import yaml

with open('config.yaml', 'r', encoding='utf-8') as f:
    cfg = yaml.safe_load(f)

cfg['local_root'] = '/content/logit-linear-selection/runs'
cfg

# %%
with open('config.yaml', 'w', encoding='utf-8') as f:
    yaml.safe_dump(cfg, f, sort_keys=False)

# %%
# !python logit_linear_selection.py

# %%
# !python training.py

# %%
# !python inverse_logit_linear_selection.py --bias dog

# %%
# !python fit_system_prompt_vector.py --preference-dataset runs/You_really_love_dogs_Dogs_are_8b18099e_OLMo-2-0425-1B-Instruct_trunc20_q0.1/datasets/preference_dataset.json --num-system-prompts 500 --num-triplets 500
